# %% [markdown]
# <a href="https://colab.research.google.com/github/Peterbamidele/DataScience_Project/blob/master/ReportOnCereal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #REPORT OF ANALYSIS ON CEREAL DATASET

# %% [markdown]
# We did an analysis on a dataset we got from kaggle.com. This dataset contains 77 cereals and details about them.
# According to healthline.com, fiber is a type of carbohydrate, so we combined it with sugars and carbo to form the carbohydrate class of food. We also combined sodium and potass to form the minerals class of food. As a result, five classes of food were derived out of the dataset.

# %% [markdown]
# ![1.png](data:image/png;base64,...)

# %% [markdown]
# ![2.png](data:image/png;base64,...)

# %% [markdown]
# #We went ahead to check for cereals with high proportion of each class of food.

# %% [markdown]
# 1.Carbohydrate:
#
# ![3.png](data:image/png;base64,...)

# %% [markdown]
# 2. Protein
#
# ![4.png](data:image/png;base64,...)

# %% [markdown]
# 3.Minerals:
# ![5.png](data:image/png;base64,...)

# %% [markdown]
# 4.Fat:
# ![6.png](data:image/png;base64,...)

# %% [markdown]
# 6.Vitamins:
# ![7.png](data:image/png;base64,...)

# %% [markdown]
# ##**From our analysis we came up with cereal recommendations for:**
#    # • Diabetic people
#    # • People with High Blood Pressure
#    # • Children with Kwashiokor
#    # • Aged people

# %% [markdown]
# According to diabetes.org.uk, people with diabetes need a lot of fiber. Based on that research we derived a cereal with a high content of fiber from our dataset
#
# ![8.png](data:image/png;base64,...)![9.png](data:image/png;base64,...)

# %% [markdown]
# #High Blood Pressure
#
# People with High Blood Pressure require Potassium, no fat and no sodium (clevelandclinic.com , healthline.com). We were able to derive cereals with an appropriate composure of those nutrients.
#
# ![11.png](data:image/png;base64,...)![12.png](data:image/png;base64,...)

# %% [markdown]
# #Kwashiokor
#
#  Research from (raisingchildren.net.au) Shows
#  Children with Kwashiokor need a lot of Protein and Vitamins.
#
#  ![13.png](data:image/png;base64,...)![15.png](data:image/png;base64,...)

# %% [markdown]
# #Aged/Elderly People
# from "eatright.org" it shows
# Elderly people need more Potassium, Fiber, Vitamins and less Sodium and fat
#
#
# ![16.png](data:image/png;base64,...)![17.png](data:image/png;base64,...)

# %% [markdown]
# From the chart above, we would recommend that elderly people take cereals like Raisin Squares and Frosted Mini-Wheats as they contain good proportions of the nutrients they require
